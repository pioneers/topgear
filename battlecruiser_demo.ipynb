# %% [markdown]
# # TopGear Battlecruiser Demo

# %%
# Cross-notebook include shim
with open("nbinclude.ipynb") as nbinclude_f: # don't rename nbinclude_f
    import IPython.nbformat.current
    get_ipython().run_cell(IPython.nbformat.current.read(nbinclude_f, 'json').worksheets[0].cells[0].input)

# %%
nbinclude("battlecruiser_widget")

# %%
bc=BattleCruiser()

# %%
bc.view

# %%
bc.cmd(10,0)

# %% [markdown]
# #Awesome!
# starcraft is great! everybody should own one!

# %%
nbinclude('gamepad_widget')

# %%
widgets.interact(drive,
                 x=JoystickFloatWidget(axis_id=1),
                 z=JoystickFloatWidget(axis_id=2))
# Out:
# <function __main__.drive>

# %%
widgets.interact(drive,
                 x=4,
                 z=1)

# %%
def drive(x,z):
    bc.cmd(x,z)
